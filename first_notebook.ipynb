# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# This cell does a simple prompt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
1 + 1
# Out:
# 2

# %%
a = 9

# %%
a = 100

# %%
a
# Out:
# 100

# %%
29 * 100
# Out:
# 2900

# %% [markdown]
# ## Heart disease project
#
# this project is aboout classifying whether or not this project is an environment.

# %%
df = pd.read_csv("43 - heart-disease.csv")

# %% [markdown]
# The following table shows heart disease information for a patient

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
df.target.value_counts().plot(kind="pie")
# Out:
# <Axes: >
