# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1, 2, 3, 4]);

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.plot(x, y);

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(x,y);
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %%
ax.set(title="Simple Plot", xlabel="X axis", ylabel="Y axis")
fig.savefig("images/sample-plot.png", dpi=200)

# %% [markdown]
# ## Making figures with Numpy arrays

# %%
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig, ax = plt.subplots()

ax.plot(x, x**2);

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
nut_butter_prices = {"Apple": 10, "Cashew": 15, "Pawpaw": 20}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), height=nut_butter_prices.values());
ax.set_title("Nut Butter Prices")
ax.set_ylabel("Prices($)");

# %%
fig, ax = plt.subplots()
ax.barh(nut_butter_prices.keys(), nut_butter_prices.values());

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots()

ax.hist(x);

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000));

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000));

# %%
car_sales = pd.read_csv("data/49 - car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("2/8/2026", periods=1000))

ts = ts.cumsum()
ts.plot();

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$,\.]', '', regex=True).astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"])
# Out:
# pandas.Series

# %%
car_sales["Price"] = car_sales["Price"] // 100
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sales Date"] = pd.date_range("3/8/2026", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2026-03-08
# 1   Honda    Red          87899      4   5000 2026-03-09
# 2  Toyota   Blue          32549      3   7000 2026-03-10
# 3     BMW  Black          11179      5  22000 2026-03-11
# 4  Nissan  White         213095      4   3500 2026-03-12
# 5  Toyota  Green          99213      4   4500 2026-03-13
# 6   Honda   Blue          45698      4   7500 2026-03-14
# 7   Honda   Blue          54738      4   7000 2026-03-15
# 8  Toyota  White          60000      4   6250 2026-03-16
# 9  Nissan  White          31600      4   9700 2026-03-17

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2026-03-08         4000
# 1   Honda    Red          87899      4   5000 2026-03-09         9000
# 2  Toyota   Blue          32549      3   7000 2026-03-10        16000
# 3     BMW  Black          11179      5  22000 2026-03-11        38000
# 4  Nissan  White         213095      4   3500 2026-03-12        41500
# 5  Toyota  Green          99213      4   4500 2026-03-13        46000
# 6   Honda   Blue          45698      4   7500 2026-03-14        53500
# 7   Honda   Blue          54738      4   7000 2026-03-15        60500
# 8  Toyota  White          60000      4   6250 2026-03-16        66750
# 9  Nissan  White          31600      4   9700 2026-03-17        76450

# %%
car_sales.plot(x="Sales Date", y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
x = np.random.rand(10, 4)
x

df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.856807  0.075219  0.773021  0.983871
# 1  0.242157  0.597938  0.149707  0.722535
# 2  0.713152  0.527562  0.311731  0.539922
# 3  0.004356  0.061138  0.274617  0.492748
# 4  0.832513  0.125128  0.076889  0.228300
# 5  0.454754  0.744880  0.440048  0.696271
# 6  0.779039  0.954699  0.085215  0.809547
# 7  0.570687  0.155193  0.600883  0.555240
# 8  0.234771  0.586014  0.054568  0.336838
# 9  0.036921  0.437836  0.914327  0.561021

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
car_sales.plot(y="Odometer (KM)", x="Make", kind="bar");

# %%
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease = pd.read_csv("data/90 - heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease.plot.hist(subplots=True, figsize=(10, 30));

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
len(over_50)
# Out:
# 208

# %%
# pyplot method

over_50.plot(x="age", y="chol", c="target", cmap="winter", alpha=0.5, kind="scatter");

# %%
#matplotlib 00 method

fix, ax = plt.subplots(figsize=(10, 6))
over_50.plot(x="age", y="chol", c="target", cmap="winter", alpha=0.5, kind="scatter", ax=ax);

# ax.set_xlim(45, 100)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

scatter = ax.scatter(x=over_50["age"], y=over_50["chol"], c=over_50["target"], cmap="winter", alpha=0.5);

ax.set(title="Heart Disease and Cholesterol Levels", xlabel="Age", ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(), title="Target");

ax.axhline(over_50["chol"].mean(), linestyle="--")

# %%
fig, (ax0, ax1) = plt.subplots(figsize=(10, 10), nrows=2, ncols=1)


scatter = ax0.scatter(x=over_50["age"], y=over_50["chol"], c=over_50["target"], cmap="winter", alpha=0.5);

ax0.set(title="Heart Disease and Cholesterol Levels", xlabel="Age", ylabel="Cholesterol");

ax0.set_xlim([50, 80])

ax0.legend(*scatter.legend_elements(), title="Target");

ax0.axhline(over_50["chol"].mean(), linestyle="--")

scatter = ax1.scatter(x=over_50["age"], y=over_50["thalach"], c=over_50["target"], cmap="winter", alpha=0.5);
ax1.set(title="Heart Disease and Maximum Heart Rate", xlabel="Age", ylabel="Maximum Heart Rate");
ax1.legend(*scatter.legend_elements(), title="Target");
ax1.axhline(over_50["thalach"].mean(), linestyle="--");

fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'petroff6',
#  'petroff8',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
plt.style.use("seaborn-v0_8-darkgrid")
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter", c="Make", cmap="winter", alpha=0.5);
# Out:
# c:\Users\HP\Downloads\ml-projects\mlxdatascience\env\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1388: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
plt.style.use("ggplot")
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
x = np.random.rand(10, 4)
x
# Out:
# array([[0.02066499, 0.22952189, 0.68011963, 0.79614089],
#        [0.57571026, 0.18702858, 0.10046079, 0.70047611],
#        [0.03169763, 0.62681815, 0.2473849 , 0.72738754],
#        [0.6185745 , 0.89641281, 0.48682687, 0.60029829],
#        [0.20525703, 0.15757515, 0.4257791 , 0.02316872],
#        [0.7198336 , 0.37720486, 0.54195337, 0.96420586],
#        [0.81907106, 0.53798447, 0.52537092, 0.09498019],
#        [0.51051296, 0.4566918 , 0.74212911, 0.8811171 ],
#        [0.91295874, 0.89905321, 0.6481879 , 0.58534868],
#        [0.96415826, 0.94258525, 0.52279166, 0.13161231]])

# %%
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.020665  0.229522  0.680120  0.796141
# 1  0.575710  0.187029  0.100461  0.700476
# 2  0.031698  0.626818  0.247385  0.727388
# 3  0.618575  0.896413  0.486827  0.600298
# 4  0.205257  0.157575  0.425779  0.023169
# 5  0.719834  0.377205  0.541953  0.964206
# 6  0.819071  0.537984  0.525371  0.094980
# 7  0.510513  0.456692  0.742129  0.881117
# 8  0.912959  0.899053  0.648188  0.585349
# 9  0.964158  0.942585  0.522792  0.131612

# %%
ax = df.plot(kind="bar")

# %%
ax = df.plot(kind="bar", title="Random Number Graph from DataFrame", xlabel="Row Number", ylabel="Random Number")

ax.legend().set_visible(True)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

scatter = ax.scatter(x=over_50["age"], y=over_50["chol"], c=over_50["target"], cmap="plasma", alpha=0.5);

ax.set(title="Heart Disease and Cholesterol Levels", xlabel="Age", ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(), title="Target");

ax.axhline(over_50["chol"].mean(), linestyle="--")
